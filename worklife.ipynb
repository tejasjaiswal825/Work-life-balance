# %%
import pandas as pd
a=pd.read_excel('work life balance.xlsx',sheet_name='main')
#a.drop_duplicates(inplace=True)
print(a.to_string())
#a.to_excel('worklife2.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 a=pd.read_excel('work life balance.xlsx',sheet_name='main')
#       3 #a.drop_duplicates(inplace=True)
#       4 print(a.to_string())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# --> 508     data = io.parse(
# ...

# %%
import pandas as pd
a=pd.read_excel('work life balance.xlsx',sheet_name=6)
print(a.to_string())
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  Quality of Sleep  Physical Activity Level  Stress Level   BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0          101  Female   36               Teacher             7.2                 8                       60             4         Normal         115/75          68         7000            NaN
# 1          102  Female   36               Teacher             7.2                 8                       60             4         Normal         115/75          68         7000            NaN
# 2          103  Female   36               Teacher             7.2                 8                       60             4         Normal         115/75          68         7000            NaN
# 3          105  Female   36               Teacher             7.2                 8                       60             4         Normal         115/75          68         7000    Sleep Apnea
# ...

# %%
a.drop_duplicates(inplace=True)
print(a.to_string())
a.to_excel('worklife3.xlsx')
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  Quality of Sleep  Physical Activity Level  Stress Level   BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0          101  Female   36               Teacher             7.2                 8                       60             4         Normal         115/75          68         7000            NaN
# 1          102  Female   36               Teacher             7.2                 8                       60             4         Normal         115/75          68         7000            NaN
# 2          103  Female   36               Teacher             7.2                 8                       60             4         Normal         115/75          68         7000            NaN
# 3          105  Female   36               Teacher             7.2                 8                       60             4         Normal         115/75          68         7000    Sleep Apnea
# ...
